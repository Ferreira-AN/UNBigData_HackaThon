# %%
import pandas as pd
import numpy as np
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif

# %% [markdown]
# # Base

# %%
df = pd.read_parquet("data/processed/interpolated_ahei.parquet")
#df.head()

# %% [markdown]
# # Prices Database

# %%
prices = pd.read_excel("data/raw/prices_for_nutrition.xlsx")
#prices.head()

# %%
#prices.tail(10)

# %%
prices_calc = prices[:-5]
prices_calc = (
    prices_calc[["Country Code", "Time"] + prices.columns.tolist()[6:]]
    .rename(columns={"Time": "Year"})
    .replace("..", np.nan)
    .interpolate()
    .convert_dtypes()
)
prices_calc
# Out:
#     Country Code  Year  Cost of an energy sufficient diet [CoCA]  \
# 0            ALB  2017                                     0.725
# 1            ALB  2018                                     0.737
# 2            ALB  2019                                     0.749
# 3            ALB  2020                                     0.761
# 4            DZA  2017                                     0.773
# ..           ...   ...                                       ...
# 739          ZMB  2020                                     0.901
# 740          ZWE  2017                                     0.775
# 741          ZWE  2018                                     0.775
# 742          ZWE  2019                                     0.775
# 743          ZWE  2020                                     0.775
#
#      Cost of a nutrient adequate diet [CoNA]  Cost of a healthy diet [CoHD]  \
# 0                                      2.471                          3.952
# 1                                      2.434                          4.051
# 2                                      2.397                          4.117
# 3                                       2.36                          4.197
# 4                                      2.323                          3.763
# ..                                       ...                            ...
# 739                                  2.31775                            3.3
# 740                                    2.297                          3.456
# 741                                    2.297                          3.456
# 742                                    2.297                          3.456
# 743                                    2.297                          3.456
#
#      Cost of a healthy diet relative to the cost of sufficient energy from starchy staples [CoHD_CoCA]  \
# 0                                                 5.45
# 1                                                5.305
# 2                                                 5.16
# 3                                                5.015
# 4                                                 4.87
# ..                                                 ...
# 739                                             3.9475
# 740                                               4.46
# 741                                               4.46
# 742                                               4.46
# 743                                               4.46
#
#      Cost of fruits [CoHD_f]  Cost of vegetables [CoHD_v]  \
# 0                      0.911                        0.707
# 1                      0.928                        0.705
# 2                      0.945                        0.703
# 3                      0.962                        0.701
# 4                      0.979                        0.699
# ..                       ...                          ...
# 739                  0.47775                      0.88375
# 740                    0.513                        0.968
# 741                    0.513                        0.968
# 742                    0.513                        0.968
# 743                    0.513                        0.968
#
#      Cost of starchy staples [CoHD_ss]  \
# 0                                0.599
# 1                              0.57325
# 2                               0.5475
# 3                              0.52175
# 4                                0.496
# ..                                 ...
# 739                              0.616
# 740                               0.55
# 741                               0.55
# 742                               0.55
# 743                               0.55
#
#      Cost of animal-source foods [CoHD_asf]  ...  \
# 0                                     1.204  ...
# 1                                     1.144  ...
# 2                                     1.084  ...
# 3                                     1.024  ...
# 4                                     0.964  ...
# ..                                      ...  ...
# 739                                   0.939  ...
# 740                                    0.95  ...
# 741                                    0.95  ...
# 742                                    0.95  ...
# 743                                    0.95  ...
#
#      Affordability of a healthy diet: ratio of cost to the $0.99 food poverty line [CoHD_pov]  \
# 0                                                3.992
# 1                                                4.092
# 2                                                4.159
# 3                                                4.239
# 4                                                3.801
# ..                                                 ...
# 739                                              3.333
# 740                                              3.491
# 741                                              3.491
# 742                                              3.491
# 743                                              3.491
#
#      Affordability of an energy sufficient diet: ratio of cost to food expenditures [CoCA_fexp]  \
# 0                                                0.078
# 1                                               0.0895
# 2                                                0.101
# 3                                               0.1125
# 4                                                0.124
# ..                                                 ...
# 739                                              0.446
# 740                                              0.343
# 741                                              0.343
# 742                                              0.343
# 743                                              0.343
#
#      Affordability of a nutrient adequate diet: ratio of cost to food expenditures [CoNA_fexp]  \
# 0                                                0.266
# 1                                                0.293
# 2                                                 0.32
# 3                                                0.347
# 4                                                0.374
# ..                                                 ...
# 739                                            1.11325
# 740                                              1.016
# 741                                              1.016
# 742                                              1.016
# 743                                              1.016
#
#      Affordability of a healthy diet: ratio of cost to food expenditures [CoHD_fexp]  \
# 0                                                0.425
# 1                                                 0.47
# 2                                                0.515
# 3                                                 0.56
# 4                                                0.605
# ..                                                 ...
# 739                                              1.602
# 740                                              1.529
# 741                                              1.529
# 742                                              1.529
# 743                                              1.529
#
#      Percent of the population who cannot afford sufficient calories at 52% of income [CoCA_headcount]  \
# 0                                                  0.0
# 1                                                 0.05
# 2                                                  0.1
# 3                                                 0.15
# 4                                                  0.2
# ..                                                 ...
# 739                                               27.8
# 740                                               15.8
# 741                                               15.8
# 742                                               15.8
# 743                                               15.8
#
#      Percent of the population who cannot afford nutrient adequacy at 52% of income [CoNA_headcount]  \
# 0                                                 13.0
# 1                                                11.55
# 2                                                 10.1
# 3                                                 8.65
# 4                                                  7.2
# ..                                                 ...
# 739                                              73.55
# 740                                               70.8
# 741                                               70.8
# 742                                               70.8
# 743                                               70.8
#
#      Percent of the population who cannot afford a healthy diet at 52% of income [CoHD_headcount]  \
# 0                                                 37.8
# 1                                                 27.9
# 2                                                 19.8
# 3                                                 20.1
# 4                                                 35.2
# ..                                                 ...
# 739                                               88.0
# 740                                               84.1
# 741                                               84.1
# 742                                               84.1
# 743                                               84.1
#
#      Millions of people who cannot afford sufficient calories at 52% of income [CoCA_unafford_n]  \
# 0                                                  0.0
# 1                                                0.025
# 2                                                 0.05
# 3                                                0.075
# 4                                                  0.1
# ..                                                 ...
# 739                                              4.325
# 740                                                2.2
# 741                                                2.2
# 742                                                2.2
# 743                                                2.2
#
#      Millions of people who cannot afford nutrient adequacy at 52% of income [CoNA_unafford_n]  \
# 0                                                  0.4
# 1                                                 1.05
# 2                                                  1.7
# 3                                                 2.35
# 4                                                  3.0
# ..                                                 ...
# 739                                             11.025
# 740                                               10.1
# 741                                               10.1
# 742                                               10.1
# 743                                               10.1
#
#      Millions of people who cannot afford a healthy diet at 52% of income [CoHD_unafford_n]
# 0                                                  1.1
# 1                                                  0.8
# 2                                                  0.6
# 3                                                  0.6
# 4                                                 14.6
# ..                                                 ...
# 739                                               16.2
# 740                                               12.0
# 741                                               12.0
# 742                                               12.0
# 743                                               12.0
#
# [744 rows x 35 columns]

# %%
prc = df.merge(prices_calc, on=["Country Code", "Year"])

# %%
x = prc.drop(['AHEI', 'Year', 'Country Code'], axis =1)
y = prc['AHEI']

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
from sklearn.feature_selection import RFE

# %%
rfe = RFE(model, 7)
# Out:
# C:\Users\Nickolas Machado\miniconda3\envs\onu\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass n_features_to_select=7 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "

# %%
fit = rfe.fit(x, y)
# Out:
# C:\Users\Nickolas Machado\miniconda3\envs\onu\lib\site-packages\sklearn\utils\validation.py:63: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   return f(*args, **kwargs)

# %%
cols1 = fit.get_support(indices=True)

# %%
feat_price = x.iloc[:,cols1].columns.to_list()
feat_price
# Out:
# ['Cost of a healthy diet [CoHD]',
#  'Cost share for fruits in a least-cost healthy diet [CoHD_f_prop]',
#  'Cost share for vegetables in a least-cost healthy diet [CoHD_v_prop]',
#  'Cost share for starchy staples in a least-cost healthy diet [CoHD_ss_prop]',
#  'Cost share for animal-sourced foods in a least-cost healthy diet [CoHD_asf_prop]',
#  'Cost share for legumes, nuts and seeds in a least-cost healthy diet [CoHD_lns_prop]',
#  'Cost share for oils and fats in a least-cost healthy diet [CoHD_of_prop]']

# %% [markdown]
# # CPI

# %%
cpi = pd.read_csv("data/raw/cpi.csv")

# %%
cpi_calc = (
    cpi.query("(FREQUENCY == 'A') and (MEASURE == 'AGRWTH')")
    [["LOCATION", "SUBJECT", "TIME", "Value"]]
    .rename(columns={"LOCATION": "Country Code", "Value": "CPI", "TIME": "Year"})
    .pivot(columns="SUBJECT", values="CPI", index=["Country Code", "Year"])
    .reset_index()
    .convert_dtypes()
    .sort_values(by=["Country Code", "Year"])
)
cpi_calc["Year"] = cpi_calc["Year"].astype("int")
cpi_calc.head()
# Out:
# SUBJECT Country Code  Year  ENRG      FOOD       TOT  TOT_FOODENRG
# 0                ARG  2018  <NA>  32.73381  34.27723          <NA>
# 1                ARG  2019  <NA>  58.36288  53.54831          <NA>
# 2                ARG  2020  <NA>  46.96305  42.01509          <NA>
# 3                ARG  2021  <NA>  49.84582  48.40938          <NA>
# 4                AUS  1950  <NA>      <NA>  8.695652          <NA>

# %%
# Food and tot may be promissing
cpp = df.merge(cpi_calc, on=["Country Code", "Year"])#.corr()["AHEI"]
#cpp[cpp['Country Code'] == "BRA"].corr()["AHEI"]

# %%
cpp = cpp.dropna()

# %%
cpp.head(2)
# Out:
#    Country Code  Year       AHEI      ENRG      FOOD       TOT  TOT_FOODENRG
# 23          AUS  1972  45.936247   4.91007  3.907289  6.024096      6.458926
# 24          AUS  1973  45.936247  3.762801  15.35854  9.090909      8.337001

# %%
x = cpp.drop(['AHEI', 'Year', 'Country Code'], axis =1)
y = cpp['AHEI']

# %%
rfe = RFE(model, 2)
# Out:
# C:\Users\Nickolas Machado\miniconda3\envs\onu\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass n_features_to_select=2 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "

# %%
fit = rfe.fit(x, y)
# Out:
# C:\Users\Nickolas Machado\miniconda3\envs\onu\lib\site-packages\sklearn\utils\validation.py:63: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   return f(*args, **kwargs)

# %%
cols2 = fit.get_support(indices=True)

# %%
feat_cpi = x.iloc[:,cols2].columns.to_list()
feat_cpi
# Out:
# ['TOT', 'TOT_FOODENRG']

# %% [markdown]
# # WDI

# %%
def long_to_wide(df: pd.DataFrame):
    cols = [col for col in df.columns if "20" in col]
    wide = df.rename(columns={"Country Code": "Country"})
    wide = wide.melt(
        id_vars=["Country", "Indicator Name"], value_vars=cols, var_name="Year", value_name="Pct"
    )
    wide = wide.set_index(["Country", "Year"]).pivot(columns="Indicator Name")
    wide.columns = [col[1] for col in wide.columns]
    return wide.reset_index()

# %%
wdi = long_to_wide(pd.read_csv("data/raw/world_development_index.csv"))
wdi
# Out:
#      Country  Year  \
# 0        ABW  2000
# 1        ABW  2001
# 2        ABW  2002
# 3        ABW  2003
# 4        ABW  2004
# ...      ...   ...
# 5847     ZWE  2017
# 5848     ZWE  2018
# 5849     ZWE  2019
# 5850     ZWE  2020
# 5851     ZWE  2021
#
#       ARI treatment (% of children under 5 taken to a health provider)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5847                                                NaN
# 5848                                                NaN
# 5849                                               48.0
# 5850                                                NaN
# 5851                                                NaN
#
#       Access to clean fuels and technologies for cooking (% of population)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5847                                               29.8
# 5848                                               29.9
# 5849                                               30.1
# 5850                                               30.4
# 5851                                                NaN
#
#       Access to clean fuels and technologies for cooking, rural (% of rural population)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5847                                                6.0
# 5848                                                6.4
# 5849                                                6.7
# 5850                                                6.8
# 5851                                                NaN
#
#       Access to clean fuels and technologies for cooking, urban (% of urban population)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5847                                               79.3
# 5848                                               79.1
# 5849                                               79.1
# 5850                                               78.6
# 5851                                                NaN
#
#       Access to electricity (% of population)  \
# 0                                   91.660400
# 1                                  100.000000
# 2                                  100.000000
# 3                                  100.000000
# 4                                  100.000000
# ...                                       ...
# 5847                                44.178635
# 5848                                45.572647
# 5849                                46.781475
# 5850                                52.747669
# 5851                                      NaN
#
#       Access to electricity, rural (% of rural population)  \
# 0                                            100.000000
# 1                                            100.000000
# 2                                            100.000000
# 3                                            100.000000
# 4                                            100.000000
# ...                                                 ...
# 5847                                          24.531088
# 5848                                          26.617121
# 5849                                          28.404877
# 5850                                          37.060249
# 5851                                                NaN
#
#       Access to electricity, urban (% of urban population)  \
# 0                                            100.000000
# 1                                            100.000000
# 2                                            100.000000
# 3                                            100.000000
# 4                                            100.000000
# ...                                                 ...
# 5847                                          85.478287
# 5848                                          85.468765
# 5849                                          85.457336
# 5850                                          85.715477
# 5851                                                NaN
#
#       Account ownership at a financial institution or with a mobile-money-service provider (% of population ages 15+)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5847                                              55.29
# 5848                                                NaN
# 5849                                                NaN
# 5850                                                NaN
# 5851                                              59.75
#
#       ...  \
# 0     ...
# 1     ...
# 2     ...
# 3     ...
# 4     ...
# ...   ...
# 5847  ...
# 5848  ...
# 5849  ...
# 5850  ...
# 5851  ...
#
#       Women who believe a husband is justified in beating his wife (any of five reasons) (%)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5847                                                NaN
# 5848                                                NaN
# 5849                                                NaN
# 5850                                                NaN
# 5851                                                NaN
#
#       Women who believe a husband is justified in beating his wife when she argues with him (%)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5847                                                NaN
# 5848                                                NaN
# 5849                                                NaN
# 5850                                                NaN
# 5851                                                NaN
#
#       Women who believe a husband is justified in beating his wife when she burns the food (%)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5847                                                NaN
# 5848                                                NaN
# 5849                                                NaN
# 5850                                                NaN
# 5851                                                NaN
#
#       Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5847                                                NaN
# 5848                                                NaN
# 5849                                                NaN
# 5850                                                NaN
# 5851                                                NaN
#
#       Women who believe a husband is justified in beating his wife when she neglects the children (%)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5847                                                NaN
# 5848                                                NaN
# 5849                                                NaN
# 5850                                                NaN
# 5851                                                NaN
#
#       Women who believe a husband is justified in beating his wife when she refuses sex with him (%)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5847                                                NaN
# 5848                                                NaN
# 5849                                                NaN
# 5850                                                NaN
# 5851                                                NaN
#
#       Women who were first married by age 15 (% of women ages 20-24)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5847                                                NaN
# 5848                                                NaN
# 5849                                           5.418352
# 5850                                                NaN
# 5851                                                NaN
#
#       Women who were first married by age 18 (% of women ages 20-24)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5847                                                NaN
# 5848                                                NaN
# 5849                                          33.658057
# 5850                                                NaN
# 5851                                                NaN
#
#       Women's share of population ages 15+ living with HIV (%)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5847                                               59.9
# 5848                                               60.1
# 5849                                               60.3
# 5850                                               60.5
# 5851                                               60.7
#
#       Young people (ages 15-24) newly infected with HIV
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5847                                            13000.0
# 5848                                            10000.0
# 5849                                             8600.0
# 5850                                             7700.0
# 5851                                             6800.0
#
# [5852 rows x 1444 columns]

# %%
wdi_calc = (
    wdi.rename(columns={"Country": "Country Code"})
    .convert_dtypes()
)
wdi_calc["Year"] = wdi_calc["Year"].astype("int")

# %%
wdi_rfe = df.merge(wdi_calc, on=["Country Code", "Year"])

# %%
x = wdi_rfe.drop(['AHEI', 'Year', 'Country Code'], axis =1)
y = wdi_rfe['AHEI']

# %%
rfe = RFE(model, 5)
# Out:
# C:\Users\Nickolas Machado\miniconda3\envs\onu\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass n_features_to_select=5 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "

# %%
fit = rfe.fit(x, y)

# %%
cols3 = fit.get_support(indices=True)

# %%
feat_wdi = x.iloc[:,cols3].columns.to_list()
feat_wdi
# Out:
# ['Human capital index (HCI) (scale 0-1)',
#  'Human capital index (HCI), lower bound (scale 0-1)',
#  'Human capital index (HCI), male (scale 0-1)',
#  'Human capital index (HCI), male, lower bound (scale 0-1)',
#  'Human capital index (HCI), upper bound (scale 0-1)']

# %%
# the other features are describes the same thing
feat_wdi = feat_wdi[:1]
feat_wdi
# Out:
# ['Human capital index (HCI) (scale 0-1)']

# %%
data_final = df.copy()
for feat_df, feat_cols in zip([wdi_rfe, cpi_calc, prices_calc], [feat_wdi, feat_cpi, feat_price]):
    data_final = data_final.merge(
        feat_df[["Country Code", "Year"] + feat_cols], on=["Country Code", "Year"], how="outer"
    )
data_final.columns
# Out:
# Index(['Country Code', 'Year', 'AHEI', 'Human capital index (HCI) (scale 0-1)',
#        'TOT', 'TOT_FOODENRG', 'Cost of a healthy diet [CoHD]',
#        'Cost share for fruits in a least-cost healthy diet [CoHD_f_prop]',
#        'Cost share for vegetables in a least-cost healthy diet [CoHD_v_prop]',
#        'Cost share for starchy staples in a least-cost healthy diet [CoHD_ss_prop]',
#        'Cost share for animal-sourced foods in a least-cost healthy diet [CoHD_asf_prop]',
#        'Cost share for legumes, nuts and seeds in a least-cost healthy diet [CoHD_lns_prop]',
#        'Cost share for oils and fats in a least-cost healthy diet [CoHD_of_prop]'],
#       dtype='object')

# %%
data_final.columns = [
    "Country", "Year", "AHEI", "HCI", "CPI", "CPIFoodEnergy",
    "HealthyDietCost", "FruitsShare", "VegetablesShare", "StarchyShare",
    "AnimalSourceShare", "LegumesShare", "OilsShare",
]
data_final
# Out:
#      Country  Year       AHEI   HCI   CPI  CPIFoodEnergy  HealthyDietCost  \
# 0        AFG  1990  51.369047  <NA>  <NA>           <NA>             <NA>
# 1        AFG  1991  51.246402  <NA>  <NA>           <NA>             <NA>
# 2        AFG  1992  51.123757  <NA>  <NA>           <NA>             <NA>
# 3        AFG  1993  51.001112  <NA>  <NA>           <NA>             <NA>
# 4        AFG  1994  50.878467  <NA>  <NA>           <NA>             <NA>
# ...      ...   ...        ...   ...   ...            ...              ...
# 7166     WLD  2020        NaN  <NA>  <NA>           <NA>            3.537
# 7167     ZMB  2019        NaN  <NA>  <NA>           <NA>            3.245
# 7168     ZMB  2020        NaN  <NA>  <NA>           <NA>              3.3
# 7169     ZWE  2019        NaN  <NA>  <NA>           <NA>            3.456
# 7170     ZWE  2020        NaN  <NA>  <NA>           <NA>            3.456
#
#       FruitsShare  VegetablesShare  StarchyShare  AnimalSourceShare  \
# 0            <NA>             <NA>          <NA>               <NA>
# 1            <NA>             <NA>          <NA>               <NA>
# 2            <NA>             <NA>          <NA>               <NA>
# 3            <NA>             <NA>          <NA>               <NA>
# 4            <NA>             <NA>          <NA>               <NA>
# ...           ...              ...           ...                ...
# 7166     0.131875           0.2005       0.25525           0.299375
# 7167       0.1345           0.2425        0.2115             0.2845
# 7168      0.14125          0.26125       0.18525            0.27975
# 7169        0.148             0.28         0.159              0.275
# 7170        0.148             0.28         0.159              0.275
#
#       LegumesShare  OilsShare
# 0             <NA>       <NA>
# 1             <NA>       <NA>
# 2             <NA>       <NA>
# 3             <NA>       <NA>
# 4             <NA>       <NA>
# ...            ...        ...
# 7166      0.072625   0.041375
# 7167         0.085      0.042
# 7168          0.09      0.042
# 7169         0.095      0.042
# 7170         0.095      0.042
#
# [7171 rows x 13 columns]

# %%
data_final.to_parquet("data/processed/features.parquet")
